# %% [markdown]
# # RDS-02 Построение модели предсказания результатов госэкзамена по математике для учеников школы
#
# Суть проекта — отследить влияние условий жизни учащихся в возрасте от 15 до 22 лет на их успеваемость по математике, чтобы на ранней стадии выявлять студентов, находящихся в группе риска.

# %% [markdown]
# ## Импорт модулей и определение функций

# %%
# импорты
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
from itertools import combinations
from scipy.stats import ttest_ind
import os
from collections import Counter

# %%
# настроить mathplotlib
# %matplotlib inline
# настроим pandas
pd.set_option('display.max_rows', 200)  # выведем больше строк
pd.set_option('display.max_columns', 80)  # выведем больше колонок

# %%
# подгрузить функции для анализа данных
from dsa import show_column_info, clear_num_col, get_boxplot, get_stat_diff, show_df_info

# %% [markdown]
# ## Изучим датасет

# %%
#адреса, пароли, явки
fn_stud_math = 'stud_math.xls'
path = r""

# загрузить датасет
studs = pd.read_csv(os.path.join(path, fn_stud_math))

# %% [markdown]
# ### Предварительный обзор датасета
#
# Предварительные наблюдения по датасету:
# 1. В датасете 395 строк
# 1. В датасете есть столбец *"studytime, granular"*, которого нет в описании датасета
# 1. Большинство столбцов имеют незначительное количество уникальных значений
# 1. Почти все столбцы имеют мало пропусков (менее 10%), однако только четверть строк не имеют ни одного пропуска в столбцах

# %%
show_df_info(studs)
# Out:
#   school sex  age address famsize Pstatus  Medu  Fedu     Mjob     Fjob  \
# 0     GP   F   18       U     NaN       A   4.0   4.0  at_home  teacher
# 1     GP   F   17       U     GT3     NaN   1.0   1.0  at_home    other
# 2     GP   F   15       U     LE3       T   1.0   1.0  at_home    other
# 3     GP   F   15       U     GT3       T   4.0   2.0   health      NaN
# 4     GP   F   16       U     GT3       T   3.0   3.0    other    other
#
#    reason guardian  traveltime  studytime  failures schoolsup famsup paid  \
# 0  course   mother         2.0        2.0       0.0       yes     no   no
# 1  course   father         1.0        2.0       0.0        no    yes   no
# 2   other   mother         1.0        2.0       3.0       yes     no  NaN
# 3    home   mother         1.0        3.0       0.0        no    yes  yes
# 4    home   father         1.0        2.0       0.0        no    yes  yes
#
#   activities nursery  studytime, granular higher internet romantic  famrel  \
# 0         no     yes                 -6.0    yes      NaN       no     4.0
# 1         no      no                 -6.0    yes      yes       no     5.0
# 2         no     yes                 -6.0    yes      yes      NaN     4.0
# 3        yes     yes                 -9.0    yes      yes      yes     3.0
# 4         no     yes                 -6.0    yes       no       no     4.0
#
#    freetime  goout  health  absences  score
# 0       3.0    4.0     3.0       6.0   30.0
# 1       3.0    3.0     3.0       4.0   30.0
# 2       3.0    2.0     3.0      10.0   50.0
# 3       2.0    2.0     5.0       2.0   75.0
# 4       3.0    2.0     5.0       4.0   50.0
# Количество строк в датасете: 395
# Cтолбцы в датасете (30):
#                  column  not_null_unique_values_count  not_null_count  \
# 0                school                             2             395
# 1                   sex                             2             395
# 2                   age                             8             395
# 3               address                             2             378
# 4               famsize                             2             368
# 5               Pstatus                             2             350
# 6                  Medu                             5             392
# 7                  Fedu                             6             371
# 8                  Mjob                             5             376
# 9                  Fjob                             5             359
# 10               reason                             4             378
# 11             guardian                             3             364
# 12           traveltime                             4             367
# 13            studytime                             4             388
# 14             failures                             4             373
# 15            schoolsup                             2             386
# 16               famsup                             2             356
# 17                 paid                             2             355
# 18           activities                             2             381
# 19              nursery                             2             379
# 20  studytime, granular                             4             388
# 21               higher                             2             375
# 22             internet                             2             361
# 23             romantic                             2             364
# 24               famrel                             6             368
# 25             freetime                             5             384
# 26                goout                             5             387
# 27               health                             5             380
# 28             absences                            36             383
# 29                score                            18             389
#
#      d_type  percent_not_null_value
# 0    object                1.000000
# 1    object                1.000000
# 2     int64                1.000000
# 3    object                0.956962
# 4    object                0.931646
# 5    object                0.886076
# 6   float64                0.992405
# 7   float64                0.939241
# 8    object                0.951899
# 9    object                0.908861
# 10   object                0.956962
# 11   object                0.921519
# 12  float64                0.929114
# 13  float64                0.982278
# 14  float64                0.944304
# 15   object                0.977215
# 16   object                0.901266
# 17   object                0.898734
# 18   object                0.964557
# 19   object                0.959494
# 20  float64                0.982278
# 21   object                0.949367
# 22   object                0.913924
# 23   object                0.921519
# 24  float64                0.931646
# 25  float64                0.972152
# 26  float64                0.979747
# 27  float64                0.962025
# 28  float64                0.969620
# 29  float64                0.984810
# Типы столбцов:
# d_type  int64  float64  object
# column      1       12      17

# %%
show_df_info(studs.dropna())
# Out:
#    school sex  age address famsize Pstatus  Medu  Fedu      Mjob     Fjob  \
# 4      GP   F   16       U     GT3       T   3.0   3.0     other    other
# 5      GP   M   16       U     LE3       T   4.0   3.0  services    other
# 7      GP   F   17       U     GT3       A   4.0   4.0     other  teacher
# 10     GP   F   15       U     GT3       T   4.0   4.0   teacher   health
# 14     GP   M   15       U     GT3       A   2.0   2.0     other    other
#
#         reason guardian  traveltime  studytime  failures schoolsup famsup  \
# 4         home   father         1.0        2.0       0.0        no    yes
# 5   reputation   mother         1.0        2.0       0.0        no    yes
# 7         home   mother         2.0        2.0       0.0       yes    yes
# 10  reputation   mother         1.0        2.0       0.0        no    yes
# 14        home    other         1.0        3.0       0.0        no    yes
#
#    paid activities nursery  studytime, granular higher internet romantic  \
# 4   yes         no     yes                 -6.0    yes       no       no
# 5   yes        yes     yes                 -6.0    yes      yes       no
# 7    no         no     yes                 -6.0    yes       no       no
# 10  yes         no     yes                 -6.0    yes      yes       no
# 14   no         no     yes                 -9.0    yes      yes      yes
#
#     famrel  freetime  goout  health  absences  score
# 4      4.0       3.0    2.0     5.0       4.0   50.0
# 5      5.0       4.0    2.0     5.0      10.0   75.0
# 7      4.0       1.0    4.0     1.0       6.0   30.0
# 10     3.0       3.0    3.0     2.0       0.0   45.0
# 14     4.0       5.0    2.0     3.0       0.0   80.0
# Количество строк в датасете: 97
# Cтолбцы в датасете (30):
#                  column  not_null_unique_values_count  not_null_count  \
# 0                school                             2              97
# 1                   sex                             2              97
# 2                   age                             7              97
# 3               address                             2              97
# 4               famsize                             2              97
# 5               Pstatus                             2              97
# 6                  Medu                             5              97
# 7                  Fedu                             4              97
# 8                  Mjob                             5              97
# 9                  Fjob                             5              97
# 10               reason                             4              97
# 11             guardian                             3              97
# 12           traveltime                             4              97
# 13            studytime                             4              97
# 14             failures                             4              97
# 15            schoolsup                             2              97
# 16               famsup                             2              97
# 17                 paid                             2              97
# 18           activities                             2              97
# 19              nursery                             2              97
# 20  studytime, granular                             4              97
# 21               higher                             2              97
# 22             internet                             2              97
# 23             romantic                             2              97
# 24               famrel                             5              97
# 25             freetime                             5              97
# 26                goout                             5              97
# 27               health                             5              97
# 28             absences                            21              97
# 29                score                            15              97
#
#      d_type  percent_not_null_value
# 0    object                     1.0
# 1    object                     1.0
# 2     int64                     1.0
# 3    object                     1.0
# 4    object                     1.0
# 5    object                     1.0
# 6   float64                     1.0
# 7   float64                     1.0
# 8    object                     1.0
# 9    object                     1.0
# 10   object                     1.0
# 11   object                     1.0
# 12  float64                     1.0
# 13  float64                     1.0
# 14  float64                     1.0
# 15   object                     1.0
# 16   object                     1.0
# 17   object                     1.0
# 18   object                     1.0
# 19   object                     1.0
# 20  float64                     1.0
# 21   object                     1.0
# 22   object                     1.0
# 23   object                     1.0
# 24  float64                     1.0
# 25  float64                     1.0
# 26  float64                     1.0
# 27  float64                     1.0
# 28  float64                     1.0
# 29  float64                     1.0
# Типы столбцов:
# d_type  int64  float64  object
# column      1       12      17

# %% [markdown]
# ### absences — количество пропущенных занятий
#
# 1. Содержит 12 пропущенных значений
# 1. Содержит потенциальные выбросы, которые можно попробовать почистить с помощью межквартильного интервала
# 1. На первый взгляд значения имеют экспонентциальный характер, но подробнее нужно рассмотреть после очистки данных.

# %%
show_column_info(studs, 'absences', bins=100, fig_size_x=18, fig_size_y=5)
# Out:
# Тип поля absences: float64
# Количество непустых значений: 383
# Количество уникальных непустых значений: 36
#     absences  count   percent
# 0        0.0    111  0.281013
# 1        1.0      3  0.007595
# 2        2.0     60  0.151899
# 3        3.0      8  0.020253
# 4        4.0     53  0.134177
# 5        5.0      5  0.012658
# 6        6.0     31  0.078481
# 7        7.0      6  0.015190
# 8        8.0     21  0.053165
# 9        9.0      3  0.007595
# 10      10.0     17  0.043038
# 11      11.0      2  0.005063
# 12      12.0     12  0.030380
# 13      13.0      2  0.005063
# 14      14.0     12  0.030380
# 15      15.0      2  0.005063
# 16      16.0      7  0.017722
# 17      17.0      1  0.002532
# 18      18.0      5  0.012658
# 19      19.0      1  0.002532
# 20      20.0      4  0.010127
# 21      21.0      1  0.002532
# 22      22.0      3  0.007595
# 23      23.0      1  0.002532
# 24      24.0      1  0.002532
# 25      25.0      1  0.002532
# 26      26.0      1  0.002532
# 27      28.0      1  0.002532
# 28      30.0      1  0.002532
# 29      38.0      1  0.002532
# 30      40.0      1  0.002532
# 31      54.0      1  0.002532
# 32      56.0      1  0.002532
# 33      75.0      1  0.002532
# 34     212.0      1  0.002532
# 35     385.0      1  0.002532
# 36       NaN     12  0.030380
# count    383.000000
# mean       7.279373
# std       23.465197
# min        0.000000
# 25%        0.000000
# 50%        4.000000
# 75%        8.000000
# max      385.000000
# Name: absences, dtype: float64

# %% [markdown]
# ### activities — дополнительные внеучебные занятия (yes или no)
# 1. Not-null значения, соответствуют ожидаемым

# %%
show_column_info(studs, 'activities')
# Out:
# Тип поля activities: object
# Количество непустых значений: 381
# Количество уникальных непустых значений: 2
#   activities  count   percent
# 0         no    186  0.470886
# 1        yes    195  0.493671
# 2        NaN     14  0.035443

# %% [markdown]
# ### address — тип адреса ученика ('U' - городской, 'R' - за городом)
#
# 1. Not-Null значения соответствуют ожидаемым

# %%
show_column_info(studs, 'address')
# Out:
# Тип поля address: object
# Количество непустых значений: 378
# Количество уникальных непустых значений: 2
#   address  count   percent
# 0       R     83  0.210127
# 1       U    295  0.746835
# 2     NaN     17  0.043038

# %% [markdown]
# ### age — возраст ученика (от 15 до 22)
#
# 1. Значения столбца имеют примерно нормальное распределение
# 1. Пропусков нет, выбросов тоже

# %%
show_column_info(studs, 'age')
# Out:
# Тип поля age: int64
# Количество непустых значений: 395
# Количество уникальных непустых значений: 8
#    age  count   percent
# 0   15     82  0.207595
# 1   16    104  0.263291
# 2   17     98  0.248101
# 3   18     82  0.207595
# 4   19     24  0.060759
# 5   20      3  0.007595
# 6   21      1  0.002532
# 7   22      1  0.002532
# count    395.000000
# mean      16.696203
# std        1.276043
# min       15.000000
# 25%       16.000000
# 50%       17.000000
# 75%       18.000000
# max       22.000000
# Name: age, dtype: float64

# %% [markdown]
# ### failures — количество внеучебных неудач (n, если 1<=n<3, иначе 4)
#
# 1. Большинство строк имеют значение 0, которое отсутствует в описании. Исходя из смысла столбца это, возможно, ошибка описания.
# 3. Значение "3" тоже отсутствует в описании - возможно это тоже ошибка описания.

# %%
show_column_info(studs, 'failures')
# Out:
# Тип поля failures: float64
# Количество непустых значений: 373
# Количество уникальных непустых значений: 4
#    failures  count   percent
# 0       0.0    293  0.741772
# 1       1.0     49  0.124051
# 2       2.0     16  0.040506
# 3       3.0     15  0.037975
# 4       NaN     22  0.055696
# count    373.000000
# mean       0.337802
# std        0.743135
# min        0.000000
# 25%        0.000000
# 50%        0.000000
# 75%        0.000000
# max        3.000000
# Name: failures, dtype: float64

# %% [markdown]
# ### famsize — размер семьи('LE3' <= 3, 'GT3' >3)
# 1. Not-Null значения соответствуют ожидаемым

# %%
show_column_info(studs, 'famsize')
# Out:
# Тип поля famsize: object
# Количество непустых значений: 368
# Количество уникальных непустых значений: 2
#   famsize  count   percent
# 0     GT3    261  0.660759
# 1     LE3    107  0.270886
# 2     NaN     27  0.068354

# %% [markdown]
# ### famsup — семейная образовательная поддержка (yes или no)
# 1. Not-Null значения соответствуют ожидаемым

# %%
show_column_info(studs, 'famsup')
# Out:
# Тип поля famsup: object
# Количество непустых значений: 356
# Количество уникальных непустых значений: 2
#   famsup  count   percent
# 0     no    137  0.346835
# 1    yes    219  0.554430
# 2    NaN     39  0.098734

# %% [markdown]
# ### famrel — семейные отношения (от 1 - очень плохо до 5 - очень хорошо)
# 1. В данных присутствует значение "-1.0", которое отсутствует в описании столбца. Имеет смысл вычистить эту строку.

# %%
show_column_info(studs, 'famrel')
# Out:
# Тип поля famrel: float64
# Количество непустых значений: 368
# Количество уникальных непустых значений: 6
#    famrel  count   percent
# 0    -1.0      1  0.002532
# 1     1.0      7  0.017722
# 2     2.0     17  0.043038
# 3     3.0     62  0.156962
# 4     4.0    182  0.460759
# 5     5.0     99  0.250633
# 6     NaN     27  0.068354
# count    368.000000
# mean       3.937500
# std        0.927277
# min       -1.000000
# 25%        4.000000
# 50%        4.000000
# 75%        5.000000
# max        5.000000
# Name: famrel, dtype: float64

# %% [markdown]
# ### Fedu — образование отца (0 - нет, 1 - 4 класса, 2 - 5-9 классы, 3 - среднее специальное или 11 классов, 4 - высшее)
# 1.Поле Fedu содержит явный выброс со значением 40, который имеет смысл почистить.

# %%
show_column_info(studs, 'Fedu')
# Out:
# Тип поля Fedu: float64
# Количество непустых значений: 371
# Количество уникальных непустых значений: 6
#    Fedu  count   percent
# 0   0.0      2  0.005063
# 1   1.0     78  0.197468
# 2   2.0    106  0.268354
# 3   3.0     96  0.243038
# 4   4.0     88  0.222785
# 5  40.0      1  0.002532
# 6   NaN     24  0.060759
# count    371.000000
# mean       2.614555
# std        2.228732
# min        0.000000
# 25%        2.000000
# 50%        2.000000
# 75%        3.000000
# max       40.000000
# Name: Fedu, dtype: float64

# %% [markdown]
# ### Fjob — работа отца ('teacher' - учитель, 'health' - сфера здравоохранения, 'services' - гос служба, 'at_home' - не работает, 'other' - другое)
#
# 1. Not-Null имеют ожидаемые значения

# %%
show_column_info(studs, 'Fjob')
# Out:
# Тип поля Fjob: object
# Количество непустых значений: 359
# Количество уникальных непустых значений: 5
#        Fjob  count   percent
# 0   at_home     16  0.040506
# 1    health     15  0.037975
# 2     other    197  0.498734
# 3  services    102  0.258228
# 4   teacher     29  0.073418
# 5       NaN     36  0.091139

# %% [markdown]
# ### freetime  — свободное время после школы (от 1 - очень мало до 5 - очень мого)
#
# 1. Not-Null имеют ожидаемые значения

# %%
show_column_info(studs, 'freetime')
# Out:
# Тип поля freetime: float64
# Количество непустых значений: 384
# Количество уникальных непустых значений: 5
#    freetime  count   percent
# 0       1.0     18  0.045570
# 1       2.0     63  0.159494
# 2       3.0    153  0.387342
# 3       4.0    112  0.283544
# 4       5.0     38  0.096203
# 5       NaN     11  0.027848
# count    384.000000
# mean       3.231771
# std        0.993940
# min        1.000000
# 25%        3.000000
# 50%        3.000000
# 75%        4.000000
# max        5.000000
# Name: freetime, dtype: float64

# %% [markdown]
# ### goout — проведение времени с друзьями (от 1 - очень мало до 5 - очень много)
# 1. Not-Null имеют ожидаемые значения

# %%
show_column_info(studs, 'goout')
# Out:
# Тип поля goout: float64
# Количество непустых значений: 387
# Количество уникальных непустых значений: 5
#    goout  count   percent
# 0    1.0     23  0.058228
# 1    2.0    101  0.255696
# 2    3.0    127  0.321519
# 3    4.0     84  0.212658
# 4    5.0     52  0.131646
# 5    NaN      8  0.020253
# count    387.000000
# mean       3.105943
# std        1.115896
# min        1.000000
# 25%        2.000000
# 50%        3.000000
# 75%        4.000000
# max        5.000000
# Name: goout, dtype: float64

# %% [markdown]
# ### guardian — опекун ('mother' - мать, 'father' - отец, 'other' - другое)
# 1. Not-Null имеют ожидаемые значения

# %%
show_column_info(studs, 'guardian')
# Out:
# Тип поля guardian: object
# Количество непустых значений: 364
# Количество уникальных непустых значений: 3
#   guardian  count   percent
# 0   father     86  0.217722
# 1   mother    250  0.632911
# 2    other     28  0.070886
# 3      NaN     31  0.078481

# %% [markdown]
# ### health — текущее состояние здоровья (от 1 - очень плохо до 5 - очень хорошо)
# 1. Not-Null имеют ожидаемые значения

# %%
show_column_info(studs, 'health')
# Out:
# Тип поля health: float64
# Количество непустых значений: 380
# Количество уникальных непустых значений: 5
#    health  count   percent
# 0     1.0     47  0.118987
# 1     2.0     43  0.108861
# 2     3.0     89  0.225316
# 3     4.0     63  0.159494
# 4     5.0    138  0.349367
# 5     NaN     15  0.037975
# count    380.000000
# mean       3.531579
# std        1.396019
# min        1.000000
# 25%        3.000000
# 50%        4.000000
# 75%        5.000000
# max        5.000000
# Name: health, dtype: float64

# %% [markdown]
# ### higher — хочет получить высшее образование (yes или no)
# 1. Not-Null имеют ожидаемые значения

# %%
show_column_info(studs, 'higher')
# Out:
# Тип поля higher: object
# Количество непустых значений: 375
# Количество уникальных непустых значений: 2
#   higher  count   percent
# 0     no     19  0.048101
# 1    yes    356  0.901266
# 2    NaN     20  0.050633

# %% [markdown]
# ### internet — наличие интернета дома (yes или no)
# 1. Not-Null имеют ожидаемые значения

# %%
show_column_info(studs, 'internet')
# Out:
# Тип поля internet: object
# Количество непустых значений: 361
# Количество уникальных непустых значений: 2
#   internet  count   percent
# 0       no     56  0.141772
# 1      yes    305  0.772152
# 2      NaN     34  0.086076

# %% [markdown]
# ### Medu — образование матери (0 - нет, 1 - 4 класса, 2 - 5-9 классы, 3 - среднее специальное или 11 классов, 4 - высшее)
# 1. Not-Null имеют ожидаемые значения

# %%
show_column_info(studs, 'Medu', bins=5)
# Out:
# Тип поля Medu: float64
# Количество непустых значений: 392
# Количество уникальных непустых значений: 5
#    Medu  count   percent
# 0   0.0      3  0.007595
# 1   1.0     59  0.149367
# 2   2.0    102  0.258228
# 3   3.0     97  0.245570
# 4   4.0    131  0.331646
# 5   NaN      3  0.007595
# count    392.000000
# mean       2.750000
# std        1.098127
# min        0.000000
# 25%        2.000000
# 50%        3.000000
# 75%        4.000000
# max        4.000000
# Name: Medu, dtype: float64

# %% [markdown]
# ### Mjob — работа матери ('teacher' - учитель, 'health' - сфера здравоохранения, 'services' - гос служба, 'at_home' - не работает, 'other' - другое)
# 1. Not-Null имеют ожидаемые значения

# %%
show_column_info(studs, 'Mjob')
# Out:
# Тип поля Mjob: object
# Количество непустых значений: 376
# Количество уникальных непустых значений: 5
#        Mjob  count   percent
# 0   at_home     58  0.146835
# 1    health     32  0.081013
# 2     other    133  0.336709
# 3  services     98  0.248101
# 4   teacher     55  0.139241
# 5       NaN     19  0.048101

# %% [markdown]
# ### nursery — посещал детский сад (yes или no)
# 1. Not-Null имеют ожидаемые значения

# %%
show_column_info(studs, 'nursery')
# Out:
# Тип поля nursery: object
# Количество непустых значений: 379
# Количество уникальных непустых значений: 2
#   nursery  count   percent
# 0      no     79  0.200000
# 1     yes    300  0.759494
# 2     NaN     16  0.040506

# %% [markdown]
# ### paid — дополнительные платные занятия по математике (yes или no)
# 1. Not-Null имеют ожидаемые значения

# %%
show_column_info(studs, 'paid')
# Out:
# Тип поля paid: object
# Количество непустых значений: 355
# Количество уникальных непустых значений: 2
#   paid  count   percent
# 0   no    200  0.506329
# 1  yes    155  0.392405
# 2  NaN     40  0.101266

# %% [markdown]
# ### Pstatus — статус совместного жилья родителей ('T' - живут вместе 'A' - раздельно)
# 1. Not-Null имеют ожидаемые значения

# %%
show_column_info(studs, 'Pstatus')
# Out:
# Тип поля Pstatus: object
# Количество непустых значений: 350
# Количество уникальных непустых значений: 2
#   Pstatus  count   percent
# 0       A     36  0.091139
# 1       T    314  0.794937
# 2     NaN     45  0.113924

# %% [markdown]
# ### reason — причина выбора школы ('home' - близость к дому, 'reputation' - репутация школы, 'course' - образовательная программа, 'other' - другое)
# 1. Not-Null имеют ожидаемые значения

# %%
show_column_info(studs, 'reason')
# Out:
# Тип поля reason: object
# Количество непустых значений: 378
# Количество уникальных непустых значений: 4
#        reason  count   percent
# 0      course    137  0.346835
# 1        home    104  0.263291
# 2       other     34  0.086076
# 3  reputation    103  0.260759
# 4         NaN     17  0.043038

# %% [markdown]
# ### romantic — в романтических отношениях (yes или no)
# 1. Not-Null имеют ожидаемые значения

# %%
show_column_info(studs, 'romantic')
# Out:
# Тип поля romantic: object
# Количество непустых значений: 364
# Количество уникальных непустых значений: 2
#   romantic  count   percent
# 0       no    240  0.607595
# 1      yes    124  0.313924
# 2      NaN     31  0.078481

# %% [markdown]
# ### school  — аббревиатура школы, в которой учится ученик
# 1. Датасет содержит данные по ученикам двух школ с аббревиатурами *GP* и *MS*

# %%
show_column_info(studs, 'school')
# Out:
# Тип поля school: object
# Количество непустых значений: 395
# Количество уникальных непустых значений: 2
#   school  count   percent
# 0     GP    349  0.883544
# 1     MS     46  0.116456

# %% [markdown]
# ### schoolsup — дополнительная образовательная поддержка (yes или no)
# 1. Not-Null имеют ожидаемые значения

# %%
show_column_info(studs, 'schoolsup')
# Out:
# Тип поля schoolsup: object
# Количество непустых значений: 386
# Количество уникальных непустых значений: 2
#   schoolsup  count   percent
# 0        no    335  0.848101
# 1       yes     51  0.129114
# 2       NaN      9  0.022785

# %% [markdown]
# ### sex — пол ученика ('F' - женский, 'M' - мужской)
# 1. Not-Null имеют ожидаемые значения

# %%
show_column_info(studs, 'sex')
# Out:
# Тип поля sex: object
# Количество непустых значений: 395
# Количество уникальных непустых значений: 2
#   sex  count   percent
# 0   F    208  0.526582
# 1   M    187  0.473418

# %% [markdown]
# ### score — баллы по госэкзамену по математике
# 1. Содержит значения в диапазоне от 0 до 100, что, вроде как, соответствует предметной области
# 1. Содержит 6 строк с пропущенными значениями, которые имеет смысл почистить
# 1. Распределение носит примерно нормальный характер

# %%
show_column_info(studs, 'score', bins=20)
# Out:
# Тип поля score: float64
# Количество непустых значений: 389
# Количество уникальных непустых значений: 18
#     score  count   percent
# 0     0.0     37  0.093671
# 1    20.0      1  0.002532
# 2    25.0      7  0.017722
# 3    30.0     15  0.037975
# 4    35.0      9  0.022785
# 5    40.0     31  0.078481
# 6    45.0     27  0.068354
# 7    50.0     54  0.136709
# 8    55.0     46  0.116456
# 9    60.0     31  0.078481
# 10   65.0     31  0.078481
# 11   70.0     27  0.068354
# 12   75.0     33  0.083544
# 13   80.0     16  0.040506
# 14   85.0      6  0.015190
# 15   90.0     12  0.030380
# 16   95.0      5  0.012658
# 17  100.0      1  0.002532
# 18    NaN      6  0.015190
# count    389.000000
# mean      52.262211
# std       22.919022
# min        0.000000
# 25%       40.000000
# 50%       55.000000
# 75%       70.000000
# max      100.000000
# Name: score, dtype: float64

# %% [markdown]
# ### studytime — время на учёбу помимо школы в неделю (1 - <2 часов, 2 - 2-5 часов, 3 - 5-10 часов, 4 - >10 часов)
# 1. Not-Null имеют ожидаемые значения

# %%
show_column_info(studs, 'studytime')
# Out:
# Тип поля studytime: float64
# Количество непустых значений: 388
# Количество уникальных непустых значений: 4
#    studytime  count   percent
# 0        1.0    103  0.260759
# 1        2.0    194  0.491139
# 2        3.0     64  0.162025
# 3        4.0     27  0.068354
# 4        NaN      7  0.017722
# count    388.000000
# mean       2.038660
# std        0.842078
# min        1.000000
# 25%        1.000000
# 50%        2.000000
# 75%        2.000000
# max        4.000000
# Name: studytime, dtype: float64

# %% [markdown]
# ### studytime, granular
# 1. Столбец отсутствует в описании набора данных

# %%
show_column_info(studs, 'studytime, granular')
# Out:
# Тип поля studytime, granular: float64
# Количество непустых значений: 388
# Количество уникальных непустых значений: 4
#    studytime, granular  count   percent
# 0                -12.0     27  0.068354
# 1                 -9.0     64  0.162025
# 2                 -6.0    194  0.491139
# 3                 -3.0    103  0.260759
# 4                  NaN      7  0.017722
# count    388.000000
# mean      -6.115979
# std        2.526235
# min      -12.000000
# 25%       -6.000000
# 50%       -6.000000
# 75%       -3.000000
# max       -3.000000
# Name: studytime, granular, dtype: float64

# %% [markdown]
# ### traveltime — время в пути до школы (1 - <15 мин., 2 - 15-30 мин., 3 - 30-60 мин., 4 - >60 мин.)
# 1. Not-Null имеют ожидаемые значения

# %%
show_column_info(studs, 'traveltime', bins=4)
# Out:
# Тип поля traveltime: float64
# Количество непустых значений: 367
# Количество уникальных непустых значений: 4
#    traveltime  count   percent
# 0         1.0    242  0.612658
# 1         2.0     96  0.243038
# 2         3.0     22  0.055696
# 3         4.0      7  0.017722
# 4         NaN     28  0.070886
# count    367.000000
# mean       1.438692
# std        0.694181
# min        1.000000
# 25%        1.000000
# 50%        1.000000
# 75%        2.000000
# max        4.000000
# Name: traveltime, dtype: float64

# %% [markdown]
# Столбец *traveltime*:
# 1. Содержит 28 (7%) пропусков
# 2. Not-Null имеют ожидаемые значения

# %% [markdown]
# ## Чистка данных

# %% [markdown]
# ### Почистить поле absences
#
# 1. После удаления выбросов стало заметно "пилообразное" распределение значений столбца - основная масса строк имеет четные значения. Возможно занятия пропускались, в основном, "парами".
# 1. Если не учитывать "пилообразный" характер распределения, то можно сказать, что оно экспоненциальное.

# %%
# Вычислить межквартильный интервал и границы допустимых значений
median = studs.absences.median()
IQR = studs.absences.quantile(0.75) - studs.absences.quantile(0.25)
low_limit = median - 1.5*IQR
high_limit = median + 1.5*IQR
print(f"Медиана: {median}")
print(f"Межквартильный интервал: {IQR}")
print(f"Нижняя граница: {low_limit} Верхняя граница: {high_limit}")
# Почистить значения
studs = clear_num_col(studs, 'absences', low_limit, high_limit)
# Out:
# Медиана: 4.0
# Межквартильный интервал: 8.0
# Нижняя граница: -8.0 Верхняя граница: 16.0

# %%
show_column_info(studs, 'absences', bins=20, fig_size_x=6, fig_size_y=3)
# Out:
# Тип поля absences: float64
# Количество непустых значений: 355
# Количество уникальных непустых значений: 17
#     absences  count   percent
# 0        0.0    111  0.302452
# 1        1.0      3  0.008174
# 2        2.0     60  0.163488
# 3        3.0      8  0.021798
# 4        4.0     53  0.144414
# 5        5.0      5  0.013624
# 6        6.0     31  0.084469
# 7        7.0      6  0.016349
# 8        8.0     21  0.057221
# 9        9.0      3  0.008174
# 10      10.0     17  0.046322
# 11      11.0      2  0.005450
# 12      12.0     12  0.032698
# 13      13.0      2  0.005450
# 14      14.0     12  0.032698
# 15      15.0      2  0.005450
# 16      16.0      7  0.019074
# 17       NaN     12  0.032698
# count    355.000000
# mean       4.166197
# std        4.358638
# min        0.000000
# 25%        0.000000
# 50%        3.000000
# 75%        6.000000
# max       16.000000
# Name: absences, dtype: float64

# %% [markdown]
# ### Почистить поле Fedu

# %%
# Убрать строки с неправильными значениями Fedu
studs = clear_num_col(studs, 'Fedu', 0, 4)
show_column_info(studs, 'Fedu')
# Out:
# Тип поля Fedu: float64
# Количество непустых значений: 344
# Количество уникальных непустых значений: 5
#    Fedu  count   percent
# 0   0.0      2  0.005464
# 1   1.0     73  0.199454
# 2   2.0    100  0.273224
# 3   3.0     87  0.237705
# 4   4.0     82  0.224044
# 5   NaN     22  0.060109
# count    344.000000
# mean       2.505814
# std        1.090628
# min        0.000000
# 25%        2.000000
# 50%        2.000000
# 75%        3.000000
# max        4.000000
# Name: Fedu, dtype: float64

# %% [markdown]
# ### Почистить поле famrel

# %%
# Убрать строки с неправильными значениями famrel
studs = clear_num_col(studs, 'famrel', 1, 5)
show_column_info(studs, 'famrel')
# Out:
# Тип поля famrel: float64
# Количество непустых значений: 341
# Количество уникальных непустых значений: 5
#    famrel  count   percent
# 0     1.0      7  0.019178
# 1     2.0     16  0.043836
# 2     3.0     55  0.150685
# 3     4.0    169  0.463014
# 4     5.0     94  0.257534
# 5     NaN     24  0.065753
# count    341.000000
# mean       3.958944
# std        0.900041
# min        1.000000
# 25%        4.000000
# 50%        4.000000
# 75%        5.000000
# max        5.000000
# Name: famrel, dtype: float64

# %% [markdown]
# ### Почистить поле score

# %%
# Убрать строки с пустыми значениями поля score
studs = clear_num_col(studs, 'score', 0, 100, include_nan=False)

show_column_info(studs, 'score', bins=20)
# Out:
# Тип поля score: float64
# Количество непустых значений: 359
# Количество уникальных непустых значений: 17
#     score  count   percent
# 0     0.0     37  0.103064
# 1    25.0      7  0.019499
# 2    30.0     12  0.033426
# 3    35.0      8  0.022284
# 4    40.0     26  0.072423
# 5    45.0     23  0.064067
# 6    50.0     51  0.142061
# 7    55.0     42  0.116992
# 8    60.0     29  0.080780
# 9    65.0     27  0.075209
# 10   70.0     27  0.075209
# 11   75.0     33  0.091922
# 12   80.0     16  0.044568
# 13   85.0      5  0.013928
# 14   90.0     10  0.027855
# 15   95.0      5  0.013928
# 16  100.0      1  0.002786
# count    359.000000
# mean      52.339833
# std       23.355675
# min        0.000000
# 25%       42.500000
# 50%       55.000000
# 75%       70.000000
# max      100.000000
# Name: score, dtype: float64

# %% [markdown]
# ### Обзор датасета после чистки данных
#
# 1. В датасете осталосьб 359 строк из 395 строк (примерно 90%), что говорит о достаточно качественном наборе данных.

# %%
show_df_info(studs)
# Out:
#   school sex  age address famsize Pstatus  Medu  Fedu     Mjob     Fjob  \
# 0     GP   F   18       U     NaN       A   4.0   4.0  at_home  teacher
# 1     GP   F   17       U     GT3     NaN   1.0   1.0  at_home    other
# 2     GP   F   15       U     LE3       T   1.0   1.0  at_home    other
# 3     GP   F   15       U     GT3       T   4.0   2.0   health      NaN
# 4     GP   F   16       U     GT3       T   3.0   3.0    other    other
#
#    reason guardian  traveltime  studytime  failures schoolsup famsup paid  \
# 0  course   mother         2.0        2.0       0.0       yes     no   no
# 1  course   father         1.0        2.0       0.0        no    yes   no
# 2   other   mother         1.0        2.0       3.0       yes     no  NaN
# 3    home   mother         1.0        3.0       0.0        no    yes  yes
# 4    home   father         1.0        2.0       0.0        no    yes  yes
#
#   activities nursery  studytime, granular higher internet romantic  famrel  \
# 0         no     yes                 -6.0    yes      NaN       no     4.0
# 1         no      no                 -6.0    yes      yes       no     5.0
# 2         no     yes                 -6.0    yes      yes      NaN     4.0
# 3        yes     yes                 -9.0    yes      yes      yes     3.0
# 4         no     yes                 -6.0    yes       no       no     4.0
#
#    freetime  goout  health  absences  score
# 0       3.0    4.0     3.0       6.0   30.0
# 1       3.0    3.0     3.0       4.0   30.0
# 2       3.0    2.0     3.0      10.0   50.0
# 3       2.0    2.0     5.0       2.0   75.0
# 4       3.0    2.0     5.0       4.0   50.0
# Количество строк в датасете: 359
# Cтолбцы в датасете (30):
#                  column  not_null_unique_values_count  not_null_count  \
# 0                school                             2             359
# 1                   sex                             2             359
# 2                   age                             8             359
# 3               address                             2             344
# 4               famsize                             2             335
# 5               Pstatus                             2             322
# 6                  Medu                             5             356
# 7                  Fedu                             5             337
# 8                  Mjob                             5             342
# 9                  Fjob                             5             326
# 10               reason                             4             342
# 11             guardian                             3             329
# 12           traveltime                             4             332
# 13            studytime                             4             352
# 14             failures                             4             340
# 15            schoolsup                             2             350
# 16               famsup                             2             327
# 17                 paid                             2             322
# 18           activities                             2             345
# 19              nursery                             2             344
# 20  studytime, granular                             4             352
# 21               higher                             2             341
# 22             internet                             2             327
# 23             romantic                             2             329
# 24               famrel                             5             335
# 25             freetime                             5             353
# 26                goout                             5             353
# 27               health                             5             344
# 28             absences                            17             348
# 29                score                            17             359
#
#      d_type  percent_not_null_value
# 0    object                1.000000
# 1    object                1.000000
# 2     int64                1.000000
# 3    object                0.958217
# 4    object                0.933148
# 5    object                0.896936
# 6   float64                0.991643
# 7   float64                0.938719
# 8    object                0.952646
# 9    object                0.908078
# 10   object                0.952646
# 11   object                0.916435
# 12  float64                0.924791
# 13  float64                0.980501
# 14  float64                0.947075
# 15   object                0.974930
# 16   object                0.910864
# 17   object                0.896936
# 18   object                0.961003
# 19   object                0.958217
# 20  float64                0.980501
# 21   object                0.949861
# 22   object                0.910864
# 23   object                0.916435
# 24  float64                0.933148
# 25  float64                0.983287
# 26  float64                0.983287
# 27  float64                0.958217
# 28  float64                0.969359
# 29  float64                1.000000
# Типы столбцов:
# d_type  int64  float64  object
# column      1       12      17

# %% [markdown]
# ## Анализ данных

# %% [markdown]
# ### Анализ числовых данных
# 1. "studytime" и "studytime, granular" - сильно кореллируют друг с другом. "studytime, granular" можно исключить из модели данных
# 1. Также заметна сильная корреляция между переменными Medu и Fedu. Вероятно можно в моделе данных можно оставить только одну, например Medu.

# %%
sns.pairplot(studs, kind='reg')

# %%
studs.corr()
# Out:
#                           age      Medu      Fedu  traveltime  studytime  \
# age                  1.000000 -0.161016 -0.159951    0.078751  -0.012158
# Medu                -0.161016  1.000000  0.623390   -0.166397   0.102167
# Fedu                -0.159951  0.623390  1.000000   -0.146647   0.018379
# traveltime           0.078751 -0.166397 -0.146647    1.000000  -0.115907
# studytime           -0.012158  0.102167  0.018379   -0.115907   1.000000
# failures             0.186248 -0.250410 -0.301685    0.064941  -0.185041
# studytime, granular  0.012158 -0.102167 -0.018379    0.115907  -1.000000
# famrel               0.055733 -0.008737 -0.024409   -0.038292   0.023563
# freetime             0.027746  0.062450  0.024664    0.006361  -0.131239
# goout                0.139188  0.048024  0.031488    0.040329  -0.044747
# health              -0.048087 -0.041884  0.006746   -0.011341  -0.080740
# absences             0.139740  0.123353  0.011882   -0.054554  -0.029761
# score               -0.171746  0.218415  0.128829   -0.075159   0.119262
#
#                      failures  studytime, granular    famrel  freetime  \
# age                  0.186248             0.012158  0.055733  0.027746
# Medu                -0.250410            -0.102167 -0.008737  0.062450
# Fedu                -0.301685            -0.018379 -0.024409  0.024664
# traveltime           0.064941             0.115907 -0.038292  0.006361
# studytime           -0.185041            -1.000000  0.023563 -0.131239
# failures             1.000000             0.185041 -0.003508  0.091166
# studytime, granular  0.185041             1.000000 -0.023563  0.131239
# famrel              -0.003508            -0.023563  1.000000  0.174717
# freetime             0.091166             0.131239  0.174717  1.000000
# goout                0.089345             0.044747  0.061751  0.284135
# health               0.098022             0.080740  0.099257  0.075823
# absences             0.065351             0.029761 -0.068348  0.087520
# score               -0.352924            -0.119262  0.066743  0.033204
#
#                         goout    health  absences     score
# age                  0.139188 -0.048087  0.139740 -0.171746
# Medu                 0.048024 -0.041884  0.123353  0.218415
# Fedu                 0.031488  0.006746  0.011882  0.128829
# traveltime           0.040329 -0.011341 -0.054554 -0.075159
# studytime           -0.044747 -0.080740 -0.029761  0.119262
# failures             0.089345  0.098022  0.065351 -0.352924
# studytime, granular  0.044747  0.080740  0.029761 -0.119262
# famrel               0.061751  0.099257 -0.068348  0.066743
# freetime             0.284135  0.075823  0.087520  0.033204
# goout                1.000000 -0.004346  0.147428 -0.117381
# health              -0.004346  1.000000 -0.030557 -0.067845
# absences             0.147428 -0.030557  1.000000  0.110058
# score               -0.117381 -0.067845  0.110058  1.000000

# %%
studs.corr()['score'].sort_values()
# Out:
# failures              -0.352924
# age                   -0.171746
# studytime, granular   -0.119262
# goout                 -0.117381
# traveltime            -0.075159
# health                -0.067845
# freetime               0.033204
# famrel                 0.066743
# absences               0.110058
# studytime              0.119262
# Fedu                   0.128829
# Medu                   0.218415
# score                  1.000000
# Name: score, dtype: float64

# %% [markdown]
# ### Анализ номинативных переменных
# 1. При уровне доверия 90% найдены статистически значимые различия для следующих столбцов:
#   * sex
#   * address
#   * paid
#   * higher
#   * romantic
#
# Эти столбцы имеет смысл включить в модель данных для следующего анализа

# %%
for col in (c for c in studs.columns if studs[c].dtype == 'object'):
    get_boxplot(studs, col, 'score')

# %%
for col in (c for c in studs.columns if studs[c].dtype == 'object'):
    get_stat_diff(studs, col, 'score', alpha=0.05)
# Out:
# Найдены статистически значимые различия для колонки sex
# Найдены статистически значимые различия для колонки address
# Найдены статистически значимые различия для колонки paid
# Найдены статистически значимые различия для колонки higher
# Найдены статистически значимые различия для колонки romantic

# %% [markdown]
# ### Анализ числовых переменных как номинативных
#
# Большинство числовых переменных на самом деле можно считать номинативными, т.к. их значения не определены предметной областью, а просто выбраны составителями набора данных.
# Такие переменные можно рассмотреть как номинативные.
#
# При таком подходе статистически значимые различия обнаружены для столбцов:
# * failures
# * Medu

# %%
clmns = ['failures', 'famsize', 'famrel', 'Fedu', 'freetime', 'goout', 'health', 'Medu', 'studytime', 'traveltime']

# %%
for col in clmns:
    get_boxplot(studs, col, 'score')

# %%
for col in clmns:
    get_stat_diff(studs, col, 'score', alpha=0.05)
# Out:
# Найдены статистически значимые различия для колонки failures
# Найдены статистически значимые различия для колонки Medu

# %% [markdown]
# ### Модель данных для дальнейшего анализа
#
# Таким образом в модель данных для дальнейшего анализа имеет смысл добавить следующие переменные:
# * absences
# * age
# * failures
# * sex
# * address
# * paid
# * higher
# * romantic
# * Medu
# * studytime
# * score

# %%
studs_model = studs.loc[:, ['absences', 'age', 'failures', 'sex', 'address', 'paid', 'higher',
                            'romantic', 'Medu', 'studytime', 'score']]

# %%
studs_model.head(10)
# Out:
#    absences  age  failures sex address paid higher romantic  Medu  studytime  \
# 0       6.0   18       0.0   F       U   no    yes       no   4.0        2.0
# 1       4.0   17       0.0   F       U   no    yes       no   1.0        2.0
# 2      10.0   15       3.0   F       U  NaN    yes      NaN   1.0        2.0
# 3       2.0   15       0.0   F       U  yes    yes      yes   4.0        3.0
# 4       4.0   16       0.0   F       U  yes    yes       no   3.0        2.0
# 5      10.0   16       0.0   M       U  yes    yes       no   4.0        2.0
# 6       0.0   16       0.0   M     NaN   no    yes       no   2.0        2.0
# 7       6.0   17       0.0   F       U   no    yes       no   4.0        2.0
# 8       0.0   15       0.0   M       U  yes    yes       no   3.0        2.0
# 9       0.0   15       0.0   M       U  yes    yes       no   3.0        2.0
#
#    score
# 0   30.0
# 1   30.0
# 2   50.0
# 3   75.0
# 4   50.0
# 5   75.0
# 6   55.0
# 7   30.0
# 8   95.0
# 9   75.0

# %%
studs_model.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 359 entries, 0 to 394
# Data columns (total 11 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   absences   348 non-null    float64
#  1   age        359 non-null    int64
#  2   failures   340 non-null    float64
#  3   sex        359 non-null    object
#  4   address    344 non-null    object
#  5   paid       322 non-null    object
#  6   higher     341 non-null    object
#  7   romantic   329 non-null    object
#  8   Medu       356 non-null    float64
#  9   studytime  352 non-null    float64
#  10  score      359 non-null    float64
# dtypes: float64(5), int64(1), object(5)
# memory usage: 43.7+ KB

# %%
sns.pairplot(studs_model, kind='reg')  # , vars = ['age', 'absences', 'score'])

# %%
studs_model.corr()
# Out:
#            absences       age  failures      Medu  studytime     score
# absences   1.000000  0.139740  0.065351  0.123353  -0.029761  0.110058
# age        0.139740  1.000000  0.186248 -0.161016  -0.012158 -0.171746
# failures   0.065351  0.186248  1.000000 -0.250410  -0.185041 -0.352924
# Medu       0.123353 -0.161016 -0.250410  1.000000   0.102167  0.218415
# studytime -0.029761 -0.012158 -0.185041  0.102167   1.000000  0.119262
# score      0.110058 -0.171746 -0.352924  0.218415   0.119262  1.000000

# %% [markdown]
# ## Выводы по датасету
#
# В результате EDA были получены следующие выводы:
# * в каждом отдельно взятом столбце мало пропущенных значений. Однако только в 25% строк все данные заполнены
# * некорректные значения и выбросы были только в столбцах с данными об образовании отца, семейных отношениях, пропущенных занятиях и оценках.
# * вцелом можно сказать, что данные достаточно чистые
# * для построения модели предлагается использовать переменные absences, age, failures, sex, address, paid, higher, romantic, Medu, studytime, score
#
# P.S.На самом деле, чтобы принимать решение о том, какие переменные стоит оставить, а какие точно удалить нужно понимать как в дальнейшем они будут использоваться. Этого понимания пока нет. К тому же, на основе моего опыта, могу предположить, что отбор влияющих на предсказания переменных может уточняться опытным путем.
